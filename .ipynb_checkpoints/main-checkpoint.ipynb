# %% [markdown]
# # Import Packages

# %%
import numpy as np
import os
from sklearn.metrics import confusion_matrix
import seaborn as sn; sn.set(font_scale=1.4)
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
from tqdm import tqdm

# %%
class_names = ['glaucoma',"normal","cataract","Diabetic retina"]
class_names_label = {class_name:i for i, class_name in enumerate(class_names)}

nb_classes = len(class_names)

IMAGE_SIZE = (64, 64)

# %% [markdown]
# # Loading the Data

# %%
def load_data():

    datasets = [r'train', r'test']

    output = []

    # Iterate through training and test sets
    for dataset in datasets:

        images = []
        labels = []

        print("Loading {}".format(dataset))

        # Iterate through each folder corresponding to a category
        for folder in os.listdir(dataset):
            label = class_names_label[folder]

            # Iterate through each image in our folder
            for file in tqdm(os.listdir(os.path.join(dataset, folder))):

                # Get the path name of the image
                img_path = os.path.join(os.path.join(dataset, folder), file)

                # Open and resize the img
                image = cv2.imread(img_path)
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                image = cv2.resize(image, IMAGE_SIZE)

                # Append the image and its corresponding label to the output
                images.append(image)
                labels.append(label)

        images = np.array(images, dtype = 'float32')
        labels = np.array(labels, dtype = 'int32')

        output.append((images, labels))

    return output

# %%
(train_images, train_labels), (test_images, test_labels) = load_data()
# Out:
# Loading train
# 100%|██████████| 1038/1038 [00:21<00:00, 49.23it/s]
# 100%|██████████| 1098/1098 [00:17<00:00, 63.02it/s]
# 100%|██████████| 1007/1007 [00:21<00:00, 46.53it/s]
# 100%|██████████| 1074/1074 [00:17<00:00, 59.91it/s]
# Loading test
# 100%|██████████| 1038/1038 [00:16<00:00, 61.66it/s]
# 100%|██████████| 1098/1098 [00:16<00:00, 65.64it/s]
# 100%|██████████| 1007/1007 [00:17<00:00, 58.83it/s]
# 100%|██████████| 1074/1074 [00:17<00:00, 60.69it/s]

# %%
n_train = train_labels.shape[0]
n_test = test_labels.shape[0]

print ("Number of training examples: {}".format(n_train))
print ("Number of testing examples: {}".format(n_test))
print ("Each image is of size: {}".format(IMAGE_SIZE))
# Out:
# Number of training examples: 4217
# Number of testing examples: 4217
# Each image is of size: (64, 64)

# %%
import pandas as pd
_, train_counts = np.unique(train_labels, return_counts=True)
_, test_counts = np.unique(test_labels, return_counts=True)

# Bar Plot
plt.figure(figsize=(8, 5))
pd.DataFrame({'Train': train_counts, 'Test': test_counts}, index=class_names).plot.bar(color=['skyblue', 'salmon'])
plt.title('Class Distribution in Train and Test Datasets')
plt.show()

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
# Display random image from the dataset
def show_random_image(class_names, images, labels):
    idx = np.random.randint(images.shape[0])
    plt.figure()
    plt.imshow(images[idx])
    plt.title(f"Random Image #{idx}: {class_names[labels[idx]]}")
    plt.axis('off')
    plt.show()

# Call function
show_random_image(class_names, train_images, train_labels)

# %%
def display_examples(class_names, images, labels):
    fig = plt.figure(figsize=(10,10))
    fig.suptitle("Examples of images of the dataset", fontsize=16)
    for i in range(5):
        plt.subplot(5,5,i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i], cmap=plt.cm.binary)
        plt.xlabel(class_names[labels[i]])
    plt.show()

# %%
display_examples(class_names, train_images, train_labels)

# %%
def plot_pixel_intensity_histogram(image):
    plt.figure(figsize=(8, 5))
    plt.hist(image.ravel(), bins=256, color='skyblue')
    plt.title('Pixel Intensity Distribution')
    plt.xlabel('Pixel Intensity')
    plt.ylabel('Frequency')
    plt.show()

# Example with a sample image from train_images
plot_pixel_intensity_histogram(train_images[0])

# %%
import seaborn as sns
df = pd.DataFrame({'Labels': train_labels, 'Feature': [np.mean(img) for img in train_images]})
plt.figure(figsize=(8, 5))
sns.violinplot(data=df, x='Labels', y='Feature', palette='muted')
plt.title('Violin Plot of Image Feature Distribution by Class')
plt.show()
# Out:
# C:\Users\SRIRA\AppData\Local\Temp\ipykernel_21596\2858814112.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='Labels', y='Feature', palette='muted')

# %% [markdown]
# PROPOSED METHODS

# %%
batch_size =15
epochs = 10
IMG_HEIGHT = 64
IMG_WIDTH = 64

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu', input_shape = (64,64, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3, 3), activation = 'relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation=tf.nn.relu),
    tf.keras.layers.Dense(4, activation=tf.nn.softmax)
])

# %%
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(train_images, train_labels, batch_size=128, epochs=10, validation_split = 0.2)
# Out:
# Epoch 1/10
# 27/27 [==============================] - 6s 183ms/step - loss: 1.0902 - accuracy: 0.5194 - val_loss: 2.1849 - val_accuracy: 0.0000e+00
# Epoch 2/10
# 27/27 [==============================] - 5s 173ms/step - loss: 0.6737 - accuracy: 0.7311 - val_loss: 2.5590 - val_accuracy: 0.0000e+00
# Epoch 3/10
# 27/27 [==============================] - 5s 176ms/step - loss: 0.5584 - accuracy: 0.7768 - val_loss: 2.2723 - val_accuracy: 0.0000e+00
# Epoch 4/10
# 27/27 [==============================] - 6s 213ms/step - loss: 0.5129 - accuracy: 0.7898 - val_loss: 2.2395 - val_accuracy: 0.0107
# Epoch 5/10
# 27/27 [==============================] - 6s 207ms/step - loss: 0.4335 - accuracy: 0.8328 - val_loss: 1.4802 - val_accuracy: 0.2050
# Epoch 6/10
# 27/27 [==============================] - 5s 190ms/step - loss: 0.4138 - accuracy: 0.8349 - val_loss: 1.4812 - val_accuracy: 0.2488
# Epoch 7/10
# 27/27 [==============================] - 5s 197ms/step - loss: 0.3683 - accuracy: 0.8473 - val_loss: 1.6309 - val_accuracy: 0.2405
# Epoch 8/10
# 27/27 [==============================] - 5s 188ms/step - loss: 0.3542 - accuracy: 0.8527 - val_loss: 1.8207 - val_accuracy: 0.2121
# Epoch 9/10
# 27/27 [==============================] - 5s 193ms/step - loss: 0.3278 - accuracy: 0.8660 - val_loss: 0.8883 - val_accuracy: 0.6860
# Epoch 10/10
# 27/27 [==============================] - 5s 184ms/step - loss: 0.2960 - accuracy: 0.8882 - val_loss: 2.2521 - val_accuracy: 0.0960

# %%
test_loss = model.evaluate(test_images, test_labels)
# Out:
# 132/132 [==============================] - 2s 17ms/step - loss: 0.6838 - accuracy: 0.7214

# %%
####resnet
import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.layers import Conv2D, Dense, MaxPooling2D, Dropout, Flatten,GlobalAveragePooling2D
from tensorflow.keras.models import Sequential

ResNet_model = tf.keras.applications.ResNet152V2(weights='imagenet', include_top=False, input_shape=(64,64, 3))

# %%
from tensorflow.keras import Model
from tensorflow.keras.layers import Conv2D, Dense, MaxPooling2D, Dropout, Flatten,GlobalAveragePooling2D
from tensorflow.keras.models import Sequential

# The last 15 layers fine tune
for layer in ResNet_model.layers[:-15]:
    layer.trainable = False

x = ResNet_model.output
x = GlobalAveragePooling2D()(x)
x = Flatten()(x)
x = Dense(units=512, activation='relu')(x)
x = Dropout(0.3)(x)
x = Dense(units=512, activation='relu')(x)
x = Dropout(0.3)(x)
output  = Dense(4, activation='softmax')(x)
model2 = Model(ResNet_model.input, output)


model2.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 3)]          0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 70, 70, 3)            0         ['input_1[0][0]']
#
#  conv1_conv (Conv2D)         (None, 32, 32, 64)           9472      ['conv1_pad[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 34, 34, 64)           0         ['conv1_conv[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 16, 16, 64)           0         ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (Ba  (None, 16, 16, 64)           256       ['pool1_pool[0][0]']
#  tchNormalization)
#
#  conv2_block1_preact_relu (  (None, 16, 16, 64)           0         ['conv2_block1_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv2_block1_1_conv (Conv2  (None, 16, 16, 64)           4096      ['conv2_block1_preact_relu[0][
#  D)                                                                 0]']
#
#  conv2_block1_1_bn (BatchNo  (None, 16, 16, 64)           256       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 16, 16, 64)           0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_pad (ZeroPa  (None, 18, 18, 64)           0         ['conv2_block1_1_relu[0][0]']
#  dding2D)
#
#  conv2_block1_2_conv (Conv2  (None, 16, 16, 64)           36864     ['conv2_block1_2_pad[0][0]']
#  D)
#
#  conv2_block1_2_bn (BatchNo  (None, 16, 16, 64)           256       ['conv2_block1_2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_2_relu (Activ  (None, 16, 16, 64)           0         ['conv2_block1_2_bn[0][0]']
#  ation)
#
#  conv2_block1_0_conv (Conv2  (None, 16, 16, 256)          16640     ['conv2_block1_preact_relu[0][
#  D)                                                                 0]']
#
#  conv2_block1_3_conv (Conv2  (None, 16, 16, 256)          16640     ['conv2_block1_2_relu[0][0]']
#  D)
#
#  conv2_block1_out (Add)      (None, 16, 16, 256)          0         ['conv2_block1_0_conv[0][0]',
#                                                                      'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (Ba  (None, 16, 16, 256)          1024      ['conv2_block1_out[0][0]']
#  tchNormalization)
#
#  conv2_block2_preact_relu (  (None, 16, 16, 256)          0         ['conv2_block2_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv2_block2_1_conv (Conv2  (None, 16, 16, 64)           16384     ['conv2_block2_preact_relu[0][
#  D)                                                                 0]']
#
#  conv2_block2_1_bn (BatchNo  (None, 16, 16, 64)           256       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 16, 16, 64)           0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_pad (ZeroPa  (None, 18, 18, 64)           0         ['conv2_block2_1_relu[0][0]']
#  dding2D)
#
#  conv2_block2_2_conv (Conv2  (None, 16, 16, 64)           36864     ['conv2_block2_2_pad[0][0]']
#  D)
#
#  conv2_block2_2_bn (BatchNo  (None, 16, 16, 64)           256       ['conv2_block2_2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_2_relu (Activ  (None, 16, 16, 64)           0         ['conv2_block2_2_bn[0][0]']
#  ation)
#
#  conv2_block2_3_conv (Conv2  (None, 16, 16, 256)          16640     ['conv2_block2_2_relu[0][0]']
#  D)
#
#  conv2_block2_out (Add)      (None, 16, 16, 256)          0         ['conv2_block1_out[0][0]',
#                                                                      'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (Ba  (None, 16, 16, 256)          1024      ['conv2_block2_out[0][0]']
#  tchNormalization)
#
#  conv2_block3_preact_relu (  (None, 16, 16, 256)          0         ['conv2_block3_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv2_block3_1_conv (Conv2  (None, 16, 16, 64)           16384     ['conv2_block3_preact_relu[0][
#  D)                                                                 0]']
#
#  conv2_block3_1_bn (BatchNo  (None, 16, 16, 64)           256       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 16, 16, 64)           0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_pad (ZeroPa  (None, 18, 18, 64)           0         ['conv2_block3_1_relu[0][0]']
#  dding2D)
#
#  conv2_block3_2_conv (Conv2  (None, 8, 8, 64)             36864     ['conv2_block3_2_pad[0][0]']
#  D)
#
#  conv2_block3_2_bn (BatchNo  (None, 8, 8, 64)             256       ['conv2_block3_2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_2_relu (Activ  (None, 8, 8, 64)             0         ['conv2_block3_2_bn[0][0]']
#  ation)
#
#  max_pooling2d_2 (MaxPoolin  (None, 8, 8, 256)            0         ['conv2_block2_out[0][0]']
#  g2D)
#
#  conv2_block3_3_conv (Conv2  (None, 8, 8, 256)            16640     ['conv2_block3_2_relu[0][0]']
#  D)
#
#  conv2_block3_out (Add)      (None, 8, 8, 256)            0         ['max_pooling2d_2[0][0]',
#                                                                      'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (Ba  (None, 8, 8, 256)            1024      ['conv2_block3_out[0][0]']
#  tchNormalization)
#
#  conv3_block1_preact_relu (  (None, 8, 8, 256)            0         ['conv3_block1_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv3_block1_1_conv (Conv2  (None, 8, 8, 128)            32768     ['conv3_block1_preact_relu[0][
#  D)                                                                 0]']
#
#  conv3_block1_1_bn (BatchNo  (None, 8, 8, 128)            512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 8, 8, 128)            0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_pad (ZeroPa  (None, 10, 10, 128)          0         ['conv3_block1_1_relu[0][0]']
#  dding2D)
#
#  conv3_block1_2_conv (Conv2  (None, 8, 8, 128)            147456    ['conv3_block1_2_pad[0][0]']
#  D)
#
#  conv3_block1_2_bn (BatchNo  (None, 8, 8, 128)            512       ['conv3_block1_2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_2_relu (Activ  (None, 8, 8, 128)            0         ['conv3_block1_2_bn[0][0]']
#  ation)
#
#  conv3_block1_0_conv (Conv2  (None, 8, 8, 512)            131584    ['conv3_block1_preact_relu[0][
#  D)                                                                 0]']
#
#  conv3_block1_3_conv (Conv2  (None, 8, 8, 512)            66048     ['conv3_block1_2_relu[0][0]']
#  D)
#
#  conv3_block1_out (Add)      (None, 8, 8, 512)            0         ['conv3_block1_0_conv[0][0]',
#                                                                      'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (Ba  (None, 8, 8, 512)            2048      ['conv3_block1_out[0][0]']
#  tchNormalization)
#
#  conv3_block2_preact_relu (  (None, 8, 8, 512)            0         ['conv3_block2_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv3_block2_1_conv (Conv2  (None, 8, 8, 128)            65536     ['conv3_block2_preact_relu[0][
#  D)                                                                 0]']
#
#  conv3_block2_1_bn (BatchNo  (None, 8, 8, 128)            512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 8, 8, 128)            0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_pad (ZeroPa  (None, 10, 10, 128)          0         ['conv3_block2_1_relu[0][0]']
#  dding2D)
#
#  conv3_block2_2_conv (Conv2  (None, 8, 8, 128)            147456    ['conv3_block2_2_pad[0][0]']
#  D)
#
#  conv3_block2_2_bn (BatchNo  (None, 8, 8, 128)            512       ['conv3_block2_2_conv[0][0]']
#  rmalization)
#
#  conv3_block2_2_relu (Activ  (None, 8, 8, 128)            0         ['conv3_block2_2_bn[0][0]']
#  ation)
#
#  conv3_block2_3_conv (Conv2  (None, 8, 8, 512)            66048     ['conv3_block2_2_relu[0][0]']
#  D)
#
#  conv3_block2_out (Add)      (None, 8, 8, 512)            0         ['conv3_block1_out[0][0]',
#                                                                      'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (Ba  (None, 8, 8, 512)            2048      ['conv3_block2_out[0][0]']
#  tchNormalization)
#
#  conv3_block3_preact_relu (  (None, 8, 8, 512)            0         ['conv3_block3_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv3_block3_1_conv (Conv2  (None, 8, 8, 128)            65536     ['conv3_block3_preact_relu[0][
#  D)                                                                 0]']
#
#  conv3_block3_1_bn (BatchNo  (None, 8, 8, 128)            512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 8, 8, 128)            0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_pad (ZeroPa  (None, 10, 10, 128)          0         ['conv3_block3_1_relu[0][0]']
#  dding2D)
#
#  conv3_block3_2_conv (Conv2  (None, 8, 8, 128)            147456    ['conv3_block3_2_pad[0][0]']
#  D)
#
#  conv3_block3_2_bn (BatchNo  (None, 8, 8, 128)            512       ['conv3_block3_2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_2_relu (Activ  (None, 8, 8, 128)            0         ['conv3_block3_2_bn[0][0]']
#  ation)
#
#  conv3_block3_3_conv (Conv2  (None, 8, 8, 512)            66048     ['conv3_block3_2_relu[0][0]']
#  D)
#
#  conv3_block3_out (Add)      (None, 8, 8, 512)            0         ['conv3_block2_out[0][0]',
#                                                                      'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (Ba  (None, 8, 8, 512)            2048      ['conv3_block3_out[0][0]']
#  tchNormalization)
#
#  conv3_block4_preact_relu (  (None, 8, 8, 512)            0         ['conv3_block4_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv3_block4_1_conv (Conv2  (None, 8, 8, 128)            65536     ['conv3_block4_preact_relu[0][
#  D)                                                                 0]']
#
#  conv3_block4_1_bn (BatchNo  (None, 8, 8, 128)            512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 8, 8, 128)            0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_pad (ZeroPa  (None, 10, 10, 128)          0         ['conv3_block4_1_relu[0][0]']
#  dding2D)
#
#  conv3_block4_2_conv (Conv2  (None, 8, 8, 128)            147456    ['conv3_block4_2_pad[0][0]']
#  D)
#
#  conv3_block4_2_bn (BatchNo  (None, 8, 8, 128)            512       ['conv3_block4_2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_2_relu (Activ  (None, 8, 8, 128)            0         ['conv3_block4_2_bn[0][0]']
#  ation)
#
#  conv3_block4_3_conv (Conv2  (None, 8, 8, 512)            66048     ['conv3_block4_2_relu[0][0]']
#  D)
#
#  conv3_block4_out (Add)      (None, 8, 8, 512)            0         ['conv3_block3_out[0][0]',
#                                                                      'conv3_block4_3_conv[0][0]']
#
#  conv3_block5_preact_bn (Ba  (None, 8, 8, 512)            2048      ['conv3_block4_out[0][0]']
#  tchNormalization)
#
#  conv3_block5_preact_relu (  (None, 8, 8, 512)            0         ['conv3_block5_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv3_block5_1_conv (Conv2  (None, 8, 8, 128)            65536     ['conv3_block5_preact_relu[0][
#  D)                                                                 0]']
#
#  conv3_block5_1_bn (BatchNo  (None, 8, 8, 128)            512       ['conv3_block5_1_conv[0][0]']
#  rmalization)
#
#  conv3_block5_1_relu (Activ  (None, 8, 8, 128)            0         ['conv3_block5_1_bn[0][0]']
#  ation)
#
#  conv3_block5_2_pad (ZeroPa  (None, 10, 10, 128)          0         ['conv3_block5_1_relu[0][0]']
#  dding2D)
#
#  conv3_block5_2_conv (Conv2  (None, 8, 8, 128)            147456    ['conv3_block5_2_pad[0][0]']
#  D)
#
#  conv3_block5_2_bn (BatchNo  (None, 8, 8, 128)            512       ['conv3_block5_2_conv[0][0]']
#  rmalization)
#
#  conv3_block5_2_relu (Activ  (None, 8, 8, 128)            0         ['conv3_block5_2_bn[0][0]']
#  ation)
#
#  conv3_block5_3_conv (Conv2  (None, 8, 8, 512)            66048     ['conv3_block5_2_relu[0][0]']
#  D)
#
#  conv3_block5_out (Add)      (None, 8, 8, 512)            0         ['conv3_block4_out[0][0]',
#                                                                      'conv3_block5_3_conv[0][0]']
#
#  conv3_block6_preact_bn (Ba  (None, 8, 8, 512)            2048      ['conv3_block5_out[0][0]']
#  tchNormalization)
#
#  conv3_block6_preact_relu (  (None, 8, 8, 512)            0         ['conv3_block6_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv3_block6_1_conv (Conv2  (None, 8, 8, 128)            65536     ['conv3_block6_preact_relu[0][
#  D)                                                                 0]']
#
#  conv3_block6_1_bn (BatchNo  (None, 8, 8, 128)            512       ['conv3_block6_1_conv[0][0]']
#  rmalization)
#
#  conv3_block6_1_relu (Activ  (None, 8, 8, 128)            0         ['conv3_block6_1_bn[0][0]']
#  ation)
#
#  conv3_block6_2_pad (ZeroPa  (None, 10, 10, 128)          0         ['conv3_block6_1_relu[0][0]']
#  dding2D)
#
#  conv3_block6_2_conv (Conv2  (None, 8, 8, 128)            147456    ['conv3_block6_2_pad[0][0]']
#  D)
#
#  conv3_block6_2_bn (BatchNo  (None, 8, 8, 128)            512       ['conv3_block6_2_conv[0][0]']
#  rmalization)
#
#  conv3_block6_2_relu (Activ  (None, 8, 8, 128)            0         ['conv3_block6_2_bn[0][0]']
#  ation)
#
#  conv3_block6_3_conv (Conv2  (None, 8, 8, 512)            66048     ['conv3_block6_2_relu[0][0]']
#  D)
#
#  conv3_block6_out (Add)      (None, 8, 8, 512)            0         ['conv3_block5_out[0][0]',
#                                                                      'conv3_block6_3_conv[0][0]']
#
#  conv3_block7_preact_bn (Ba  (None, 8, 8, 512)            2048      ['conv3_block6_out[0][0]']
#  tchNormalization)
#
#  conv3_block7_preact_relu (  (None, 8, 8, 512)            0         ['conv3_block7_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv3_block7_1_conv (Conv2  (None, 8, 8, 128)            65536     ['conv3_block7_preact_relu[0][
#  D)                                                                 0]']
#
#  conv3_block7_1_bn (BatchNo  (None, 8, 8, 128)            512       ['conv3_block7_1_conv[0][0]']
#  rmalization)
#
#  conv3_block7_1_relu (Activ  (None, 8, 8, 128)            0         ['conv3_block7_1_bn[0][0]']
#  ation)
#
#  conv3_block7_2_pad (ZeroPa  (None, 10, 10, 128)          0         ['conv3_block7_1_relu[0][0]']
#  dding2D)
#
#  conv3_block7_2_conv (Conv2  (None, 8, 8, 128)            147456    ['conv3_block7_2_pad[0][0]']
#  D)
#
#  conv3_block7_2_bn (BatchNo  (None, 8, 8, 128)            512       ['conv3_block7_2_conv[0][0]']
#  rmalization)
#
#  conv3_block7_2_relu (Activ  (None, 8, 8, 128)            0         ['conv3_block7_2_bn[0][0]']
#  ation)
#
#  conv3_block7_3_conv (Conv2  (None, 8, 8, 512)            66048     ['conv3_block7_2_relu[0][0]']
#  D)
#
#  conv3_block7_out (Add)      (None, 8, 8, 512)            0         ['conv3_block6_out[0][0]',
#                                                                      'conv3_block7_3_conv[0][0]']
#
#  conv3_block8_preact_bn (Ba  (None, 8, 8, 512)            2048      ['conv3_block7_out[0][0]']
#  tchNormalization)
#
#  conv3_block8_preact_relu (  (None, 8, 8, 512)            0         ['conv3_block8_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv3_block8_1_conv (Conv2  (None, 8, 8, 128)            65536     ['conv3_block8_preact_relu[0][
#  D)                                                                 0]']
#
#  conv3_block8_1_bn (BatchNo  (None, 8, 8, 128)            512       ['conv3_block8_1_conv[0][0]']
#  rmalization)
#
#  conv3_block8_1_relu (Activ  (None, 8, 8, 128)            0         ['conv3_block8_1_bn[0][0]']
#  ation)
#
#  conv3_block8_2_pad (ZeroPa  (None, 10, 10, 128)          0         ['conv3_block8_1_relu[0][0]']
#  dding2D)
#
#  conv3_block8_2_conv (Conv2  (None, 4, 4, 128)            147456    ['conv3_block8_2_pad[0][0]']
#  D)
#
#  conv3_block8_2_bn (BatchNo  (None, 4, 4, 128)            512       ['conv3_block8_2_conv[0][0]']
#  rmalization)
#
#  conv3_block8_2_relu (Activ  (None, 4, 4, 128)            0         ['conv3_block8_2_bn[0][0]']
#  ation)
#
#  max_pooling2d_3 (MaxPoolin  (None, 4, 4, 512)            0         ['conv3_block7_out[0][0]']
#  g2D)
#
#  conv3_block8_3_conv (Conv2  (None, 4, 4, 512)            66048     ['conv3_block8_2_relu[0][0]']
#  D)
#
#  conv3_block8_out (Add)      (None, 4, 4, 512)            0         ['max_pooling2d_3[0][0]',
#                                                                      'conv3_block8_3_conv[0][0]']
#
#  conv4_block1_preact_bn (Ba  (None, 4, 4, 512)            2048      ['conv3_block8_out[0][0]']
#  tchNormalization)
#
#  conv4_block1_preact_relu (  (None, 4, 4, 512)            0         ['conv4_block1_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv4_block1_1_conv (Conv2  (None, 4, 4, 256)            131072    ['conv4_block1_preact_relu[0][
#  D)                                                                 0]']
#
#  conv4_block1_1_bn (BatchNo  (None, 4, 4, 256)            1024      ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 4, 4, 256)            0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_pad (ZeroPa  (None, 6, 6, 256)            0         ['conv4_block1_1_relu[0][0]']
#  dding2D)
#
#  conv4_block1_2_conv (Conv2  (None, 4, 4, 256)            589824    ['conv4_block1_2_pad[0][0]']
#  D)
#
#  conv4_block1_2_bn (BatchNo  (None, 4, 4, 256)            1024      ['conv4_block1_2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_2_relu (Activ  (None, 4, 4, 256)            0         ['conv4_block1_2_bn[0][0]']
#  ation)
#
#  conv4_block1_0_conv (Conv2  (None, 4, 4, 1024)           525312    ['conv4_block1_preact_relu[0][
#  D)                                                                 0]']
#
#  conv4_block1_3_conv (Conv2  (None, 4, 4, 1024)           263168    ['conv4_block1_2_relu[0][0]']
#  D)
#
#  conv4_block1_out (Add)      (None, 4, 4, 1024)           0         ['conv4_block1_0_conv[0][0]',
#                                                                      'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (Ba  (None, 4, 4, 1024)           4096      ['conv4_block1_out[0][0]']
#  tchNormalization)
#
#  conv4_block2_preact_relu (  (None, 4, 4, 1024)           0         ['conv4_block2_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv4_block2_1_conv (Conv2  (None, 4, 4, 256)            262144    ['conv4_block2_preact_relu[0][
#  D)                                                                 0]']
#
#  conv4_block2_1_bn (BatchNo  (None, 4, 4, 256)            1024      ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 4, 4, 256)            0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_pad (ZeroPa  (None, 6, 6, 256)            0         ['conv4_block2_1_relu[0][0]']
#  dding2D)
#
#  conv4_block2_2_conv (Conv2  (None, 4, 4, 256)            589824    ['conv4_block2_2_pad[0][0]']
#  D)
#
#  conv4_block2_2_bn (BatchNo  (None, 4, 4, 256)            1024      ['conv4_block2_2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_2_relu (Activ  (None, 4, 4, 256)            0         ['conv4_block2_2_bn[0][0]']
#  ation)
#
#  conv4_block2_3_conv (Conv2  (None, 4, 4, 1024)           263168    ['conv4_block2_2_relu[0][0]']
#  D)
#
#  conv4_block2_out (Add)      (None, 4, 4, 1024)           0         ['conv4_block1_out[0][0]',
#                                                                      'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (Ba  (None, 4, 4, 1024)           4096      ['conv4_block2_out[0][0]']
#  tchNormalization)
#
#  conv4_block3_preact_relu (  (None, 4, 4, 1024)           0         ['conv4_block3_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv4_block3_1_conv (Conv2  (None, 4, 4, 256)            262144    ['conv4_block3_preact_relu[0][
#  D)                                                                 0]']
#
#  conv4_block3_1_bn (BatchNo  (None, 4, 4, 256)            1024      ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 4, 4, 256)            0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_pad (ZeroPa  (None, 6, 6, 256)            0         ['conv4_block3_1_relu[0][0]']
#  dding2D)
#
#  conv4_block3_2_conv (Conv2  (None, 4, 4, 256)            589824    ['conv4_block3_2_pad[0][0]']
#  D)
#
#  conv4_block3_2_bn (BatchNo  (None, 4, 4, 256)            1024      ['conv4_block3_2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_2_relu (Activ  (None, 4, 4, 256)            0         ['conv4_block3_2_bn[0][0]']
#  ation)
#
# ...
#  atchNormalization)
#
#  conv4_block36_preact_relu   (None, 4, 4, 1024)           0         ['conv4_block36_preact_bn[0][0
#  (Activation)                                                       ]']
#
#  conv4_block36_1_conv (Conv  (None, 4, 4, 256)            262144    ['conv4_block36_preact_relu[0]
#  2D)                                                                [0]']
#
#  conv4_block36_1_bn (BatchN  (None, 4, 4, 256)            1024      ['conv4_block36_1_conv[0][0]']
#  ormalization)
#
#  conv4_block36_1_relu (Acti  (None, 4, 4, 256)            0         ['conv4_block36_1_bn[0][0]']
#  vation)
#
#  conv4_block36_2_pad (ZeroP  (None, 6, 6, 256)            0         ['conv4_block36_1_relu[0][0]']
#  adding2D)
#
#  conv4_block36_2_conv (Conv  (None, 2, 2, 256)            589824    ['conv4_block36_2_pad[0][0]']
#  2D)
#
#  conv4_block36_2_bn (BatchN  (None, 2, 2, 256)            1024      ['conv4_block36_2_conv[0][0]']
#  ormalization)
#
#  conv4_block36_2_relu (Acti  (None, 2, 2, 256)            0         ['conv4_block36_2_bn[0][0]']
#  vation)
#
#  max_pooling2d_4 (MaxPoolin  (None, 2, 2, 1024)           0         ['conv4_block35_out[0][0]']
#  g2D)
#
#  conv4_block36_3_conv (Conv  (None, 2, 2, 1024)           263168    ['conv4_block36_2_relu[0][0]']
#  2D)
#
#  conv4_block36_out (Add)     (None, 2, 2, 1024)           0         ['max_pooling2d_4[0][0]',
#                                                                      'conv4_block36_3_conv[0][0]']
#
#  conv5_block1_preact_bn (Ba  (None, 2, 2, 1024)           4096      ['conv4_block36_out[0][0]']
#  tchNormalization)
#
#  conv5_block1_preact_relu (  (None, 2, 2, 1024)           0         ['conv5_block1_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv5_block1_1_conv (Conv2  (None, 2, 2, 512)            524288    ['conv5_block1_preact_relu[0][
#  D)                                                                 0]']
#
#  conv5_block1_1_bn (BatchNo  (None, 2, 2, 512)            2048      ['conv5_block1_1_conv[0][0]']
#  rmalization)
#
#  conv5_block1_1_relu (Activ  (None, 2, 2, 512)            0         ['conv5_block1_1_bn[0][0]']
#  ation)
#
#  conv5_block1_2_pad (ZeroPa  (None, 4, 4, 512)            0         ['conv5_block1_1_relu[0][0]']
#  dding2D)
#
#  conv5_block1_2_conv (Conv2  (None, 2, 2, 512)            2359296   ['conv5_block1_2_pad[0][0]']
#  D)
#
#  conv5_block1_2_bn (BatchNo  (None, 2, 2, 512)            2048      ['conv5_block1_2_conv[0][0]']
#  rmalization)
#
#  conv5_block1_2_relu (Activ  (None, 2, 2, 512)            0         ['conv5_block1_2_bn[0][0]']
#  ation)
#
#  conv5_block1_0_conv (Conv2  (None, 2, 2, 2048)           2099200   ['conv5_block1_preact_relu[0][
#  D)                                                                 0]']
#
#  conv5_block1_3_conv (Conv2  (None, 2, 2, 2048)           1050624   ['conv5_block1_2_relu[0][0]']
#  D)
#
#  conv5_block1_out (Add)      (None, 2, 2, 2048)           0         ['conv5_block1_0_conv[0][0]',
#                                                                      'conv5_block1_3_conv[0][0]']
#
#  conv5_block2_preact_bn (Ba  (None, 2, 2, 2048)           8192      ['conv5_block1_out[0][0]']
#  tchNormalization)
#
#  conv5_block2_preact_relu (  (None, 2, 2, 2048)           0         ['conv5_block2_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv5_block2_1_conv (Conv2  (None, 2, 2, 512)            1048576   ['conv5_block2_preact_relu[0][
#  D)                                                                 0]']
#
#  conv5_block2_1_bn (BatchNo  (None, 2, 2, 512)            2048      ['conv5_block2_1_conv[0][0]']
#  rmalization)
#
#  conv5_block2_1_relu (Activ  (None, 2, 2, 512)            0         ['conv5_block2_1_bn[0][0]']
#  ation)
#
#  conv5_block2_2_pad (ZeroPa  (None, 4, 4, 512)            0         ['conv5_block2_1_relu[0][0]']
#  dding2D)
#
#  conv5_block2_2_conv (Conv2  (None, 2, 2, 512)            2359296   ['conv5_block2_2_pad[0][0]']
#  D)
#
#  conv5_block2_2_bn (BatchNo  (None, 2, 2, 512)            2048      ['conv5_block2_2_conv[0][0]']
#  rmalization)
#
#  conv5_block2_2_relu (Activ  (None, 2, 2, 512)            0         ['conv5_block2_2_bn[0][0]']
#  ation)
#
#  conv5_block2_3_conv (Conv2  (None, 2, 2, 2048)           1050624   ['conv5_block2_2_relu[0][0]']
#  D)
#
#  conv5_block2_out (Add)      (None, 2, 2, 2048)           0         ['conv5_block1_out[0][0]',
#                                                                      'conv5_block2_3_conv[0][0]']
#
#  conv5_block3_preact_bn (Ba  (None, 2, 2, 2048)           8192      ['conv5_block2_out[0][0]']
#  tchNormalization)
#
#  conv5_block3_preact_relu (  (None, 2, 2, 2048)           0         ['conv5_block3_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv5_block3_1_conv (Conv2  (None, 2, 2, 512)            1048576   ['conv5_block3_preact_relu[0][
#  D)                                                                 0]']
#
#  conv5_block3_1_bn (BatchNo  (None, 2, 2, 512)            2048      ['conv5_block3_1_conv[0][0]']
#  rmalization)
#
#  conv5_block3_1_relu (Activ  (None, 2, 2, 512)            0         ['conv5_block3_1_bn[0][0]']
#  ation)
#
#  conv5_block3_2_pad (ZeroPa  (None, 4, 4, 512)            0         ['conv5_block3_1_relu[0][0]']
#  dding2D)
#
#  conv5_block3_2_conv (Conv2  (None, 2, 2, 512)            2359296   ['conv5_block3_2_pad[0][0]']
#  D)
#
#  conv5_block3_2_bn (BatchNo  (None, 2, 2, 512)            2048      ['conv5_block3_2_conv[0][0]']
#  rmalization)
#
#  conv5_block3_2_relu (Activ  (None, 2, 2, 512)            0         ['conv5_block3_2_bn[0][0]']
#  ation)
#
#  conv5_block3_3_conv (Conv2  (None, 2, 2, 2048)           1050624   ['conv5_block3_2_relu[0][0]']
#  D)
#
#  conv5_block3_out (Add)      (None, 2, 2, 2048)           0         ['conv5_block2_out[0][0]',
#                                                                      'conv5_block3_3_conv[0][0]']
#
#  post_bn (BatchNormalizatio  (None, 2, 2, 2048)           8192      ['conv5_block3_out[0][0]']
#  n)
#
#  post_relu (Activation)      (None, 2, 2, 2048)           0         ['post_bn[0][0]']
#
#  global_average_pooling2d (  (None, 2048)                 0         ['post_relu[0][0]']
#  GlobalAveragePooling2D)
#
#  flatten_1 (Flatten)         (None, 2048)                 0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense_2 (Dense)             (None, 512)                  1049088   ['flatten_1[0][0]']
#
#  dropout (Dropout)           (None, 512)                  0         ['dense_2[0][0]']
#
#  dense_3 (Dense)             (None, 512)                  262656    ['dropout[0][0]']
#
#  dropout_1 (Dropout)         (None, 512)                  0         ['dense_3[0][0]']
#
#  dense_4 (Dense)             (None, 4)                    2052      ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 59645444 (227.53 MB)
# Trainable params: 6833156 (26.07 MB)
# Non-trainable params: 52812288 (201.46 MB)
# __________________________________________________________________________________________________

# %%
model2.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model2.fit(train_images, train_labels, batch_size=128, epochs=2, validation_split = 0.2)
# Out:
# Epoch 1/2
# 27/27 [==============================] - 77s 3s/step - loss: 0.7115 - accuracy: 0.7367 - val_loss: 13.9985 - val_accuracy: 0.0000e+00
# Epoch 2/2
# 27/27 [==============================] - 70s 3s/step - loss: 0.3220 - accuracy: 0.8784 - val_loss: 12.2321 - val_accuracy: 0.0071

# %%
test_loss = model2.evaluate(test_images, test_labels)
# Out:
# 132/132 [==============================] - 69s 524ms/step - loss: 4.6035 - accuracy: 0.5824

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Flatten, Dense
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import categorical_crossentropy

# Image dimensions for VGG19
height = 64
width = 64
channels = 3
num_classes = 4  # Change according to your dataset

# Input tensor
input_tensor = Input(shape=(height, width, channels))

# Load VGG19 base model
base_model = VGG19(weights='imagenet', include_top=False, input_tensor=input_tensor)

# Add classification head
x = Flatten()(base_model.output)
output = Dense(num_classes, activation='softmax')(x)
model3 = Model(inputs=base_model.input, outputs=output)

# Freeze all layers
for layer in model3.layers:
    layer.trainable = False

# Unfreeze last few layers for fine-tuning
for layer in model3.layers[-16:]:
    layer.trainable = True
    print("Layer '%s' is trainable" % layer.name)

# Compile model
opt = Adam(learning_rate=0.001)
model3.compile(optimizer=opt, loss=categorical_crossentropy, metrics=['accuracy'])

# Model summary
model3.summary()

# Callbacks
checkpoint = ModelCheckpoint("vgg19_disease.h5", monitor='val_accuracy', verbose=1,
                             save_best_only=True, save_weights_only=False, mode='auto')

early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=20, verbose=1, mode='auto')

# Assuming `train_images` and `train_labels` are already loaded
# Resize images to match VGG19 input
train_images_resized = tf.image.resize(train_images, (height, width))

model3.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])


# Fit model
history = model3.fit(
    train_images_resized,
    train_labels,
    batch_size=128,
    epochs=2,
    validation_split=0.2,
    callbacks=[checkpoint, early]
)
# Out:
# Layer 'block3_conv2' is trainable
# Layer 'block3_conv3' is trainable
# Layer 'block3_conv4' is trainable
# Layer 'block3_pool' is trainable
# Layer 'block4_conv1' is trainable
# Layer 'block4_conv2' is trainable
# Layer 'block4_conv3' is trainable
# Layer 'block4_conv4' is trainable
# Layer 'block4_pool' is trainable
# Layer 'block5_conv1' is trainable
# Layer 'block5_conv2' is trainable
# Layer 'block5_conv3' is trainable
# Layer 'block5_conv4' is trainable
# Layer 'block5_pool' is trainable
# Layer 'flatten_4' is trainable
# Layer 'dense_7' is trainable
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 64, 64, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 64, 64, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 64, 64, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 32, 32, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 32, 32, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 32, 32, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 16, 16, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 16, 16, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 16, 16, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 16, 16, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 16, 16, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 8, 8, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 8, 8, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block4_conv4 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_conv4 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  flatten_4 (Flatten)         (None, 2048)              0
#
#  dense_7 (Dense)             (None, 4)                 8196
#
# =================================================================
# Total params: 20032580 (76.42 MB)
# Trainable params: 19477252 (74.30 MB)
# Non-trainable params: 555328 (2.12 MB)
# _________________________________________________________________
# Epoch 1/2
# 27/27 [==============================] - ETA: 0s - loss: 6.4932 - accuracy: 0.3125
# Epoch 1: val_accuracy improved from -inf to 0.00000, saving model to vgg19_disease.h5
# C:\Users\SRIRA\anaconda3\envs\opthalamic\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 27/27 [==============================] - 208s 8s/step - loss: 6.4932 - accuracy: 0.3125 - val_loss: 3.5513 - val_accuracy: 0.0000e+00
# Epoch 2/2
# 27/27 [==============================] - ETA: 0s - loss: 1.2829 - accuracy: 0.3110
# Epoch 2: val_accuracy did not improve from 0.00000
# 27/27 [==============================] - 206s 8s/step - loss: 1.2829 - accuracy: 0.3110 - val_loss: 2.4357 - val_accuracy: 0.0000e+00

# %%
test_loss = model3.evaluate(test_images, test_labels)
# Out:
# 132/132 [==============================] - 60s 453ms/step - loss: 1.5084 - accuracy: 0.2599

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, Dropout, LayerNormalization, Reshape
from keras.utils import to_categorical

# Simulate or load your dataset
# Replace this with your actual data
# Example: 1000 grayscale "patch" images of shape (16, 8, 1)
X = np.random.rand(1000, 16, 8, 1)
y = np.random.randint(0, 4, size=(1000,))  # 4-class classification

# One-hot encode labels
y_encoded = to_categorical(y)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Normalize
scaler = StandardScaler()
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# Model
model = Sequential()
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same', input_shape=(16, 8, 1)))
model.add(LayerNormalization())
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(y_encoded.shape[1], activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train
model.fit(X_train, y_train, epochs=10, batch_size=16, validation_data=(X_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[44], line 6
#       4 from tensorflow.keras.models import Sequential
#       5 from tensorflow.keras.layers import Conv2D, Flatten, Dense, Dropout, LayerNormalization, Reshape
# ----> 6 from tensorflow.keras.utils import to_categorical
#       8 # Simulate or load your dataset
#       9 # Replace this with your actual data
#      10 # Example: 1000 grayscale "patch" images of shape (16, 8, 1)
#      11 X = np.random.rand(1000, 16, 8, 1)
#
# ModuleNotFoundError: No module named 'tensorflow.keras.utils'

# %%
predictions = vit_model.predict(test_images)     # Vector of probabilities
pred_labels = np.argmax(predictions, axis = 1) # We take the highest probability


index = np.random.randint(test_images.shape[0])
plt.figure()
plt.imshow(test_images[index])
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.title('Image #{} : '.format(index) + class_names[pred_labels[index]])
plt.show()

# %%
CM = confusion_matrix(test_labels, pred_labels)
ax = plt.axes()
sn.heatmap(CM, annot=True,
           annot_kws={"size": 10},
           xticklabels=class_names,
           yticklabels=class_names, ax = ax)
ax.set_title('Confusion matrix')
plt.show()

# %%
from sklearn.metrics import classification_report, precision_score, recall_score, f1_score, accuracy_score

# Assuming CM is your confusion matrix, and you have class_names defined

# Calculate overall precision, recall, and F1 score
overall_precision = precision_score(test_labels, pred_labels, average='weighted')
overall_recall = recall_score(test_labels, pred_labels, average='weighted')
overall_f1 = f1_score(test_labels, pred_labels, average='weighted')

# Calculate custom accuracy
custom_accuracy = accuracy_score(test_labels, pred_labels)

print(f'Precision: {overall_precision}')
print(f'Recall: {overall_recall}')
print(f'F1 Score: {overall_f1}')
print(f'Custom Accuracy: {custom_accuracy}')

# %%
# Generate and print classification report
print("\nClassification Report:")
print(classification_report(test_labels, pred_labels, target_names=class_names))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# Assuming test_labels and pred_labels are available

# Generate classification report
report = classification_report(test_labels, pred_labels, output_dict=True)

# Convert the classification report to a DataFrame
report_df = pd.DataFrame(report).transpose()

# Plotting the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(report_df.iloc[:-1, :].astype(float), annot=True, cmap="YlGnBu", fmt=".2f")
plt.title('Classification Report')
plt.show()

# %%
model3.save_weights("model_vgg.weights.h5")
print("Saved model to disk")

# %%
model_json=model3.to_json()
with open("model_vgg.json", "w") as json_file:
    json_file.write(model_json)
